# %% [markdown]
# # Notebook Imports

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from tqdm import tqdm
from sklearn.model_selection import RandomizedSearchCV

import statistics
from statistics import mode

import joblib

import time

# %% [markdown]
# <a id='sp1p_link'></a>
# ### Second Pick - Phase 1

# %%
df_reshaped = pd.read_pickle('./data_final.pickle')
# defining features and targets

# selected features for the 1st iter with Ordinal Encoding
sp_1p_features = df_reshaped[['left_pick_order_1', 'left_pick_order_2', 
                              'right_pick_order_1',
                              'left_attack_damage_1', 'left_attack_damage_2',
                              'left_receive_damage_1', 'left_receive_damage_2',
                              'left_kill_count_1', 'left_kill_count_2',
                              'right_attack_damage_1',
                              'right_receive_damage_1', 
                              'right_kill_count_1',
                              'left_attribute_cd_1', 'left_attribute_cd_2', 
                              'left_job_cd_1', 'left_job_cd_2',
                              'right_hero_code_1', 
                              'right_attribute_cd_1', 
                              'right_job_cd_1', 
#                              'left_postban', 'right_postban',
                              'left_preban_1', 'left_preban_2', 
                              'right_preban_1', 'right_preban_2',
                              'first_pick', 'is_win']]

sp_1p_target = df_reshaped[['left_hero_code_1', 'left_hero_code_2']]

X_train_sp_1p, X_test_sp_1p, y_train_sp_1p, y_test_sp_1p = train_test_split(sp_1p_features, sp_1p_target, test_size= 0.2, shuffle = True, random_state= 890)



# Scaling 
# Define numeric labels
sp_1p_numeric = ['left_attack_damage_1', 'left_attack_damage_2',
                 'left_receive_damage_1', 'left_receive_damage_2', 
                 'left_kill_count_1', 'left_kill_count_2',
                 'right_attack_damage_1',
                 'right_receive_damage_1', 
                 'right_kill_count_1']

# %%
# Scale numeric features
sp_1p_scaler = StandardScaler()
sp_1p_scaler.fit(X_train_sp_1p[sp_1p_numeric])
# Out:
# StandardScaler()

# %%
X_train_sp_1p_trans = pd.DataFrame()
X_test_sp_1p_trans = pd.DataFrame()

X_train_sp_1p_trans[sp_1p_numeric] = sp_1p_scaler.transform(X_train_sp_1p[sp_1p_numeric])
X_test_sp_1p_trans[sp_1p_numeric] = sp_1p_scaler.transform(X_test_sp_1p[sp_1p_numeric])

# %%
# Encoding the categorical features
# Initializing an ordinal encoder for categorical variables
sp_1p_enc = OrdinalEncoder(handle_unknown = 'use_encoded_value', unknown_value = -1)
# categorical labels for the 1st iter
sp_1p_categorical = ['left_attribute_cd_1', 'left_attribute_cd_2',
                     'left_job_cd_1', 'left_job_cd_2',
                     'right_hero_code_1',
                     'right_attribute_cd_1',
                     'right_job_cd_1', 
#                     'left_postban', 'right_postban',
                     'left_preban_1', 'left_preban_2',
                     'right_preban_1', 'right_preban_2']

X_train_sp_1p_trans[sp_1p_categorical] = sp_1p_enc.fit_transform(X_train_sp_1p[sp_1p_categorical].to_numpy())
X_test_sp_1p_trans[sp_1p_categorical] = sp_1p_enc.transform(X_test_sp_1p[sp_1p_categorical].to_numpy())

# %%
X_train_sp_1p_trans.index
X_test_sp_1p_trans.index
# Out:
# RangeIndex(start=0, stop=1979, step=1)

# %%
X_train_sp_1p.index
X_test_sp_1p.index
# Out:
# RangeIndex(start=0, stop=1979, step=1)

# %%
X_test_sp_1p.isna().sum()
X_test_sp_1p_trans.isna().sum()
# Out:
# left_attack_damage_1      0
# left_attack_damage_2      0
# left_receive_damage_1     0
# left_receive_damage_2     0
# left_kill_count_1         0
# left_kill_count_2         0
# right_attack_damage_1     0
# right_receive_damage_1    0
# right_kill_count_1        0
# left_attribute_cd_1       0
# left_attribute_cd_2       0
# left_job_cd_1             0
# left_job_cd_2             0
# right_hero_code_1         0
# right_attribute_cd_1      0
# right_job_cd_1            0
# left_preban_1             0
# left_preban_2             0
# right_preban_1            0
# right_preban_2            0
# dtype: int64

# %%
X_test_sp_1p_trans.shape
# Out:
# (1979, 20)

# %%
X_test_sp_1p.shape
# Out:
# (1979, 25)

# %%
# add features left out of scaling
l0f_sp_1p = ['left_pick_order_1', 'left_pick_order_2',
             'right_pick_order_1', 
             'first_pick', 'is_win']

X_train_sp_1p_trans[l0f_sp_1p] = X_train_sp_1p[l0f_sp_1p]
X_test_sp_1p_trans[l0f_sp_1p] = X_test_sp_1p[l0f_sp_1p]

# %%
X_test_sp_1p_trans[l0f_sp_1p]
# Out:
#       left_pick_order_1  left_pick_order_2  right_pick_order_1  first_pick  \
# 0                     1                  2                   1           0
# 1                     1                  2                   1           0
# 2                     1                  2                   1           1
# 3                     1                  2                   1           0
# 4                     1                  2                   1           0
# ...                 ...                ...                 ...         ...
# 1974                  1                  2                   1           0
# 1975                  1                  2                   1           0
# 1976                  1                  2                   1           0
# 1977                  1                  2                   1           1
# 1978                  1                  2                   1           1
#
#       is_win
# 0          2
# 1          2
# 2          2
# 3          1
# 4          2
# ...      ...
# 1974       2
# 1975       1
# 1976       2
# 1977       1
# 1978       2
#
# [1979 rows x 5 columns]

# %% [markdown]
# <a id='sp1p_link'></a>
# ### Tunning Hyperparameters for the Second Pick - Phase 1

# %%
X_test_sp_1p_trans.isna().sum()
# Out:
# left_attack_damage_1      0
# left_attack_damage_2      0
# left_receive_damage_1     0
# left_receive_damage_2     0
# left_kill_count_1         0
# left_kill_count_2         0
# right_attack_damage_1     0
# right_receive_damage_1    0
# right_kill_count_1        0
# left_attribute_cd_1       0
# left_attribute_cd_2       0
# left_job_cd_1             0
# left_job_cd_2             0
# right_hero_code_1         0
# right_attribute_cd_1      0
# right_job_cd_1            0
# left_preban_1             0
# left_preban_2             0
# right_preban_1            0
# right_preban_2            0
# left_pick_order_1         0
# left_pick_order_2         0
# right_pick_order_1        0
# first_pick                0
# is_win                    0
# dtype: int64

# %%
# Create a copy of training data after encoding
new_X_train_sp_1p = X_train_sp_1p.copy()

# %%
X_train_sp_1p.columns
# Out:
# Index(['left_pick_order_1', 'left_pick_order_2', 'right_pick_order_1',
#        'left_attack_damage_1', 'left_attack_damage_2', 'left_receive_damage_1',
#        'left_receive_damage_2', 'left_kill_count_1', 'left_kill_count_2',
#        'right_attack_damage_1', 'right_receive_damage_1', 'right_kill_count_1',
#        'left_attribute_cd_1', 'left_attribute_cd_2', 'left_job_cd_1',
#        'left_job_cd_2', 'right_hero_code_1', 'right_attribute_cd_1',
#        'right_job_cd_1', 'left_preban_1', 'left_preban_2', 'right_preban_1',
#        'right_preban_2', 'first_pick', 'is_win'],
#       dtype='object')

# %%
# Change columns names in the copied data to concatinate with the original data
new_X_train_sp_1p.columns = ['left_pick_order_1_orig', 'left_pick_order_2_orig', 
                             'right_pick_order_1_orig', 
                             'left_attack_damage_1_orig', 'left_attack_damage_2_orig',
                             'left_receive_damage_1_orig', 'left_receive_damage_2_orig',
                             'left_kill_count_1_orig', 'left_kill_count_2_orig', 
                             'right_attack_damage_1_orig', 
                             'right_receive_damage_1_orig', 
                             'right_kill_count_1_orig', 
                             'left_attribute_cd_1_orig', 'left_attribute_cd_2_orig',
                             'left_job_cd_1_orig', 'left_job_cd_2_orig',
                             'right_hero_code_1_orig',
                             'right_attribute_cd_1_orig', 
                             'right_job_cd_1_orig',
                             'left_preban_1_orig', 'left_preban_2_orig',
                             'right_preban_1_orig', 'right_preban_2_orig',
                             'first_pick_orig', 'is_win_orig']

# %%
len(new_X_train_sp_1p.columns)
# Out:
# 25

# %%
# Cocatenate original data with encoded data for later use in the function
dict_sp_1p = pd.concat((X_train_sp_1p_trans,new_X_train_sp_1p.reset_index(drop=True)), axis= 1).copy()
len(dict_sp_1p.columns)
# Out:
# 50

# %%
dict_sp_1p[['right_hero_code_1', 'right_hero_code_1_orig']]
# Out:
#       right_hero_code_1 right_hero_code_1_orig
# 0                   3.0        Ambitious Tywin
# 1                  30.0                   Laia
# 2                  15.0       Death Dealer Ray
# 3                  30.0                   Laia
# 4                  41.0          New Moon Luna
# ...                 ...                    ...
# 7908               17.0     Dragon Bride Senya
# 7909               41.0          New Moon Luna
# 7910               41.0          New Moon Luna
# 7911               30.0                   Laia
# 7912               49.0    Sea Phantom Politis
#
# [7913 rows x 2 columns]

# %% [markdown]
# <a id='sp1p_link'></a>
# ### Tunning Hyperparameters for the Second Pick - Phase 1

# %%
# RandomizedSearchCV parameters
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 10)]
# Number of features to consider at every split
max_features = ['sqrt', 'log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 50, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'estimator__n_estimators': n_estimators,
               'estimator__max_features': max_features,
               'estimator__max_depth': max_depth,
               'estimator__min_samples_split': min_samples_split,
               'estimator__min_samples_leaf': min_samples_leaf,
               'estimator__bootstrap': bootstrap}
print(random_grid)
{'bootstrap': [True, False],
 'max_depth': [10, 14, 18, 22, 26, 30, 34, 38, 42, 46, 50, None],
 'max_features': ['sqrt', 'log2'],
 'min_samples_leaf': [1, 2, 4],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [200, 288, 377, 466, 555, 644, 733, 822, 911, 1000]}
# Out:
# {'estimator__n_estimators': [200, 288, 377, 466, 555, 644, 733, 822, 911, 1000], 'estimator__max_features': ['sqrt', 'log2'], 'estimator__max_depth': [10, 14, 18, 22, 26, 30, 34, 38, 42, 46, 50, None], 'estimator__min_samples_split': [2, 5, 10], 'estimator__min_samples_leaf': [1, 2, 4], 'estimator__bootstrap': [True, False]}
# {'bootstrap': [True, False],
#  'max_depth': [10, 14, 18, 22, 26, 30, 34, 38, 42, 46, 50, None],
#  'max_features': ['sqrt', 'log2'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [200, 288, 377, 466, 555, 644, 733, 822, 911, 1000]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = MultiOutputClassifier(RandomForestClassifier())
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=890)
# Fit the random search model
rf_random.fit(X_train_sp_1p_trans, y_train_sp_1p)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   4.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   4.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   5.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=466; total time=   5.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=466; total time=   6.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=466; total time=   5.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  11.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  11.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  11.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=733; total time=  12.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=733; total time=  12.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=733; total time=  12.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=555; total time=   7.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=555; total time=   7.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=555; total time=   7.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=555; total time=   7.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=555; total time=   7.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=555; total time=   7.0s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=733; total time=  11.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=733; total time=  11.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=733; total time=  11.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   2.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   2.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   2.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   2.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=288; total time=   5.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=288; total time=   5.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=288; total time=   5.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.0s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   4.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  12.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  12.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  12.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  10.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  10.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  10.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   5.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=42, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   6.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=42, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   6.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=42, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   6.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=733; total time=  13.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=733; total time=  13.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=733; total time=  13.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   8.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   8.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   8.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=644; total time=   7.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=644; total time=   7.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=644; total time=   7.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  14.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  14.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  14.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=644; total time=  11.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=644; total time=  11.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=644; total time=  11.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=911; total time=  11.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=911; total time=  11.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=911; total time=  11.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  20.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  20.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  20.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   7.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   7.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   7.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   5.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   5.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   5.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  14.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  14.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  14.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   3.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   3.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   3.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  10.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  10.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  10.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   4.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   4.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   4.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  10.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  10.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  10.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=644; total time=   8.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=644; total time=   8.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=644; total time=   8.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   3.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  11.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  11.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  11.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   7.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   7.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   7.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=1000; total time=  11.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=1000; total time=  11.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=1000; total time=  11.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=288; total time=   6.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=288; total time=   6.0s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=288; total time=   6.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  17.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  17.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  17.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  18.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  18.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  18.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   9.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   9.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   9.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   5.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   5.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   5.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   4.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   3.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   5.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   5.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   5.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=822; total time=   9.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=822; total time=   9.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=822; total time=   9.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   8.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   8.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=466; total time=   8.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=911; total time=  11.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=911; total time=  11.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=911; total time=  11.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   5.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   5.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   5.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   9.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   9.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   9.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=1000; total time=  16.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=1000; total time=  16.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=1000; total time=  16.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   2.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   2.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   2.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  13.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  13.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=822; total time=  13.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=911; total time=  16.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=911; total time=  16.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=911; total time=  17.0s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   5.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   5.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   5.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=555; total time=  10.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=555; total time=  10.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=26, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=555; total time=  10.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=911; total time=   9.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=911; total time=   9.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=911; total time=   9.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  12.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  12.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  12.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  12.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  12.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  12.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   9.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   9.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   9.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   9.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   9.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=466; total time=   9.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=911; total time=  17.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=911; total time=  17.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=911; total time=  17.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  18.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  18.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  18.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   4.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   4.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=288; total time=   4.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   4.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   4.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   4.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  11.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  11.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  11.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   5.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   5.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   5.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=555; total time=   7.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=555; total time=   7.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=555; total time=   7.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  17.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  17.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=1000; total time=  17.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=34, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=466; total time=   5.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=466; total time=   5.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=466; total time=   5.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   7.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   7.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   7.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  11.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  11.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  11.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  10.2s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  10.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=822; total time=  10.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=555; total time=  10.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=555; total time=  10.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=555; total time=  10.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   2.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   2.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=14, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   2.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   6.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   6.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=46, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=555; total time=   7.0s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  13.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  13.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=733; total time=  13.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   5.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   5.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=10, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   6.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  13.3s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  13.1s
# [CV] END estimator__bootstrap=True, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=1000; total time=  13.4s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=10, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=288; total time=   2.8s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   7.3s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   7.4s
# [CV] END estimator__bootstrap=False, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=377; total time=   7.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  11.0s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  10.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  11.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  12.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  12.2s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  12.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=555; total time=  11.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=555; total time=  11.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=42, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=555; total time=  12.1s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   6.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   6.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=18, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=377; total time=   6.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   4.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   4.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=377; total time=   4.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__bootstrap=False, estimator__max_depth=14, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   3.7s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   2.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   2.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=22, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   2.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.9s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.8s
# [CV] END estimator__bootstrap=True, estimator__max_depth=50, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=644; total time=   8.9s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.6s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.5s
# [CV] END estimator__bootstrap=False, estimator__max_depth=38, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=644; total time=  10.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  11.5s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  11.6s
# [CV] END estimator__bootstrap=True, estimator__max_depth=26, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=911; total time=  11.8s
# RandomizedSearchCV(cv=3,
#                    estimator=MultiOutputClassifier(estimator=RandomForestClassifier()),
#                    n_iter=100,
#                    param_distributions={'estimator__bootstrap': [True, False],
#                                         'estimator__max_depth': [10, 14, 18, 22,
#                                                                  26, 30, 34, 38,
#                                                                  42, 46, 50,
#                                                                  None],
#                                         'estimator__max_features': ['sqrt',
#                                                                     'log2'],
#                                         'estimator__min_samples_leaf': [1, 2,
#                                                                         4],
#                                         'estimator__min_samples_split': [2, 5,
#                                                                          10],
#                                         'estimator__n_estimators': [200, 288,
#                                                                     377, 466,
#                                                                     555, 644,
#                                                                     733, 822,
#                                                                     911,
#                                                                     1000]},
#                    random_state=890, verbose=2)

# %%
# View the best parameters from fitting the random search
rf_random.best_params_
# Out:
# {'estimator__n_estimators': 555,
#  'estimator__min_samples_split': 2,
#  'estimator__min_samples_leaf': 1,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_depth': 42,
#  'estimator__bootstrap': False}

# %%
# Using RandomForestClassifier for multioutput and evaluaing the result after Ordinal Encoding
classifier_sp_1p = MultiOutputClassifier(RandomForestClassifier(random_state=890, max_depth = 42, n_estimators=555, min_samples_split = 2, min_samples_leaf = 1, max_features = 'sqrt', bootstrap = False))
classifier_sp_1p.fit(X_train_sp_1p_trans, y_train_sp_1p)
sp_1p_predictions= classifier_sp_1p.predict(X_test_sp_1p_trans)
classifier_sp_1p.score(X_test_sp_1p_trans, y_test_sp_1p)
# Out:
# 0.786255684689237

# %%
#saving the model
joblib.dump(classifier_sp_1p, './saved_files/classifier_sp_1p.joblib')
# Out:
# ['classifier_sp_1p.joblib']
